# %%
import numpy as np

import pandas as pd

from pandas import Series,DataFrame

# %%
import webbrowser

website = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'

webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division
# 0               1960         882    NFC East
# 1               1921       1,336   NFC North
# 2               1920       1,370   NFC North
# 3               1966         800    AFC East
# 4               1960         884    AFC East

# %%
nfl_frame.columns
# Out:
# Index([u'Rank ', u'Team ', u'Won ', u'Lost ', u'Tied ', u'Pct. ',
#        u'First NFL Season ', u'Total Games ', u'Division'],
#       dtype='object')

# %%
nfl_frame['Rank ']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank , dtype: int64

# %%
nfl_frame['Total Games ']
# Out:
# 0      882
# 1    1,336
# 2    1,370
# 3      800
# 4      884
# Name: Total Games , dtype: object

# %%
DataFrame(nfl_frame, columns=['Team ', 'First NFL Season ','Total Games '])
# Out:
#                       Team   First NFL Season  Total Games
# 0           Dallas Cowboys                1960         882
# 1        Green Bay Packers                1921       1,336
# 2            Chicago Bears                1920       1,370
# 3           Miami Dolphins                1966         800
# 4  New England Patriots[b]                1960         884

# %%
DataFrame(nfl_frame, columns=['Team ', 'First NFL Season ','Total Games ','Stadium '])
# Out:
#                       Team   First NFL Season  Total Games   Stadium
# 0           Dallas Cowboys                1960         882        NaN
# 1        Green Bay Packers                1921       1,336        NaN
# 2            Chicago Bears                1920       1,370        NaN
# 3           Miami Dolphins                1966         800        NaN
# 4  New England Patriots[b]                1960         884        NaN

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division
# 0               1960         882    NFC East
# 1               1921       1,336   NFC North
# 2               1920       1,370   NFC North
# 3               1966         800    AFC East
# 4               1960         884    AFC East

# %%
nfl_frame.head()
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division
# 0               1960         882    NFC East
# 1               1921       1,336   NFC North
# 2               1920       1,370   NFC North
# 3               1966         800    AFC East
# 4               1960         884    AFC East

# %%
# by default it will show 5 first rows, until you explicitly set the number of rows you need

# %%
nfl_frame.head(3)
# Out:
#    Rank                Team   Won   Lost   Tied   Pct.   First NFL Season   \
# 0      1     Dallas Cowboys    502    374      6  0.573               1960
# 1      2  Green Bay Packers    737    562     37  0.565               1921
# 2      3      Chicago Bears    749    579     42  0.562               1920
#
#   Total Games    Division
# 0         882    NFC East
# 1       1,336   NFC North
# 2       1,370   NFC North

# %%
nfl_frame.tail()
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division
# 0               1960         882    NFC East
# 1               1921       1,336   NFC North
# 2               1920       1,370   NFC North
# 3               1966         800    AFC East
# 4               1960         884    AFC East

# %%
# by default it will show 5 last rows, until you explicitly set the number of rows you need

# %%
# you can also grab rows you need by index, using ix method

# %%
nfl_frame.ix[3]
# Out:
# /home/oksa/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Rank                               4
# Team                 Miami Dolphins
# Won                              445
# Lost                             351
# Tied                               4
# Pct.                           0.559
# First NFL Season                1966
# Total Games                     800
# Division                    AFC East
# Name: 3, dtype: object

# %%
nfl_frame.loc[3]
# Out:
# Rank                               4
# Team                 Miami Dolphins
# Won                              445
# Lost                             351
# Tied                               4
# Pct.                           0.559
# First NFL Season                1966
# Total Games                     800
# Division                    AFC East
# Name: 3, dtype: object

# %%
nfl_frame.iloc[3]
# Out:
# Rank                               4
# Team                 Miami Dolphins
# Won                              445
# Lost                             351
# Tied                               4
# Pct.                           0.559
# First NFL Season                1966
# Total Games                     800
# Division                    AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium '] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division        Stadium
# 0               1960         882    NFC East  Levi's Stadium
# 1               1921       1,336   NFC North  Levi's Stadium
# 2               1920       1,370   NFC North  Levi's Stadium
# 3               1966         800    AFC East  Levi's Stadium
# 4               1960         884    AFC East  Levi's Stadium

# %%
nfl_frame['Stadium '] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division  Stadium   Stadium
# 0               1960         882    NFC East         0        0
# 1               1921       1,336   NFC North         1        1
# 2               1920       1,370   NFC North         2        2
# 3               1966         800    AFC East         3        3
# 4               1960         884    AFC East         4        4

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium '] = stadiums

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division        Stadium   Stadium
# 0               1960         882    NFC East    AT&T Stadium        0
# 1               1921       1,336   NFC North             NaN        1
# 2               1920       1,370   NFC North             NaN        2
# 3               1966         800    AFC East             NaN        3
# 4               1960         884    AFC East  Levi's Stadium        4

# %%
del nfl_frame['Stadium ']

# %%
nfl_frame
# Out:
#    Rank                      Team   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys    502    374      6  0.573
# 1      2        Green Bay Packers    737    562     37  0.565
# 2      3            Chicago Bears    749    579     42  0.562
# 3      4           Miami Dolphins    445    351      4  0.559
# 4      5  New England Patriots[b]    489    386      9  0.558
#
#    First NFL Season  Total Games    Division
# 0               1960         882    NFC East
# 1               1921       1,336   NFC North
# 2               1920       1,370   NFC North
# 3               1966         800    AFC East
# 4               1960         884    AFC East

# %%
data = {'City':['SF','LA','NYC'], 'Population':[837000,3880000,840000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 840000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC      840000
