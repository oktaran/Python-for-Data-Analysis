# %%
# Standard 
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
dataset1
# Out:
# array([ 1.90419505, -1.51708278,  2.36557183,  0.17380213,  1.08882352,
#         0.185696  , -1.43048279, -0.30018841,  0.65443634,  0.15916816,
#         0.98118664, -1.27466533,  0.49661856, -1.04496331,  1.37041942,
#         0.53650058,  0.33774452,  1.4122018 ,  0.35707019,  0.70149872,
#         1.49220842,  1.61873661, -0.29804041,  0.97190112, -0.06955443,
#         0.51450044, -0.60968559, -2.56773959, -0.24118016,  0.02839209,
#         0.43452616,  2.20977277, -0.20442147, -0.37476871, -2.16649505,
#        -0.29822525,  0.47704169,  0.02854321, -0.38531186,  1.15446114,
#         0.75806068, -1.38194657,  0.13583483, -1.42839653, -0.16202781,
#        -2.1693026 , -1.51018011,  0.46581956,  0.15032749,  0.32321227,
#        -0.78278593, -0.83505207,  2.25633753, -1.15128072,  0.05734773,
#        -0.97768257, -0.53215657, -0.49859169,  2.11639456,  0.34918917,
#         0.695689  , -0.10444302,  0.96574866,  1.42836627,  0.54490891,
#         0.61892896,  1.14783065, -0.95214555, -0.09920621,  1.95052867,
#        -0.01524314, -0.00569512, -1.31164544,  0.22416865,  0.76963774,
#         1.24373213, -0.82215595, -0.04158411, -0.88406768, -0.74178613,
#         1.56208895,  1.91613923,  0.3516115 ,  0.42714169, -0.82204842,
#        -1.19525884,  0.15857144, -0.17104784, -0.0737427 ,  0.89132575,
#        -0.43245482,  0.60107523, -0.2107885 , -0.02120267,  0.74904318,
#        -0.14850348,  0.33196991, -0.95476122,  0.19727927, -1.06598483])

# %%
# by default matplotlib pyplot will distribute your data into 10 bins and create histogram based on this

# %%
plt.hist(dataset1)
# Out:
# (array([ 3.,  0.,  9., 12., 15., 24., 16.,  9.,  5.,  7.]),
#  array([-2.56773959, -2.07440845, -1.58107731, -1.08774616, -0.59441502,
#         -0.10108388,  0.39224726,  0.8855784 ,  1.37890954,  1.87224069,
#          2.36557183]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 4.,  8.,  8., 14., 14., 19.,  6.,  4.,  2.,  1.]),
#  array([-1.91911396, -1.45469147, -0.99026899, -0.5258465 , -0.06142402,
#          0.40299847,  0.86742095,  1.33184344,  1.79626592,  2.26068841,
#          2.7251109 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, alpha=0.5, bins=20)
# Out:
# (array([ 2.,  2.,  5.,  3.,  5.,  3.,  6.,  8.,  7.,  7.,  9., 10.,  3.,
#          3.,  4.,  0.,  0.,  2.,  0.,  1.]),
#  array([-1.91911396, -1.68690271, -1.45469147, -1.22248023, -0.99026899,
#         -0.75805774, -0.5258465 , -0.29363526, -0.06142402,  0.17078723,
#          0.40299847,  0.63520971,  0.86742095,  1.0996322 ,  1.33184344,
#          1.56405468,  1.79626592,  2.02847717,  2.26068841,  2.49289965,
#          2.7251109 ]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)
# Out:
# /home/oksa/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/oksa/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(data1, data2, kind='hex')
# Out:
# /home/oksa/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/oksa/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
