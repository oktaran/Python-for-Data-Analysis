# %%
# Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# Stats
from scipy import stats

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Plots to appear in iPython notebook
# %matplotlib inline

# %%
dataset = randn(25)

# %%
sns.rugplot(dataset)

# %%
plt.hist(dataset, alpha=0.5)
sns.rugplot(dataset)

# %%
sns.kdeplot(dataset)
